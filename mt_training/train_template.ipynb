# %%
from datasets import load_dataset

dataset = load_dataset("Thecoder3281f/MIT_separated", "normal")

# %%
dataset

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.pre_tokenizers import Whitespace
from transformers import PreTrainedTokenizerFast

# %%
# Build vocab from your space-tokenized SMILES
def build_vocab_from_dataset(dataset, fields=["input", "target"]):
    vocab = set()
    splits = ["train", "val", "test"]
    for split in splits:
        for ex in dataset[split]:
            for f in fields:
                vocab.update(ex[f].split())

    return vocab

vocab = build_vocab_from_dataset(dataset)
vocab.update(["[PAD]", "[UNK]", "<s>", "</s>"])

#print(vocab)
vocab = {tok: i for i, tok in enumerate(sorted(vocab), start=0)}

#print(vocab)

# Create WordLevel tokenizer
tok = Tokenizer(WordLevel(vocab=vocab, unk_token="[UNK]"))
tok.pre_tokenizer = Whitespace()

# Wrap as a Hugging Face tokenizer
hf_tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=tok,
    unk_token="[UNK]",
    pad_token="[PAD]",
    eos_token="</s>",
    bos_token="<s>",
)

hf_tokenizer.save_pretrained("smiles-whitespace-tokenizer-separated-mit")

# %%
tokenizer = PreTrainedTokenizerFast.from_pretrained("smiles-whitespace-tokenizer-separated-mit")

def preprocess(batch):
    model_inputs = tokenizer(
        batch["input"],
        padding="max_length",
        truncation=True,
        max_length=256,
    )
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            batch["target"],
            padding="max_length",
            truncation=True,
            max_length=256,
        )
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_datasets = dataset.map(preprocess, batched=True, remove_columns=["input", "target"])
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 409035
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 40000
#     })
#     val: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 30000
#     })
# })

# %%
tokenized_datasets["train"][0]["attention_mask"]  # Example of tokenized input

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device() if torch.cuda.is_available() else "CPU")
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 2060

# %%
import logging
import numpy as np

# set up logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs

def canonicalize(smiles):
    """Join tokens, parse to molecule, return canonical SMILES or None."""
    try:
        s = smiles.replace(" ", "")
        mol = Chem.MolFromSmiles(s)
        if mol is None:
            return None
        return Chem.MolToSmiles(mol, canonical=True)
    except Exception:
        return None

def tanimoto(a, b):
    """Compute Tanimoto similarity between two SMILES."""
    try:
        ma, mb = Chem.MolFromSmiles(a), Chem.MolFromSmiles(b)
        if not ma or not mb:
            return 0
        fa = AllChem.GetMorganFingerprintAsBitVect(ma, 2)
        fb = AllChem.GetMorganFingerprintAsBitVect(mb, 2)
        return DataStructs.TanimotoSimilarity(fa, fb)
    except Exception:
        return 0

def compute_metrics(eval_pred, tokenizer):
    preds, labels = eval_pred

    # handle tuple
    if isinstance(preds, tuple):
        preds = preds[0]

    # convert logits to token IDs if needed
    preds = np.array(preds)
    if preds.ndim == 3:  # (batch, seq_len, vocab_size)
        preds = np.argmax(preds, axis=-1)

    labels = np.array(labels)


    # 🧠 handle both top-1 and top-k outputs
    if preds.ndim == 3:  # (batch, k, seq_len)
        batch_size, k, seq_len = preds.shape
        preds = preds.reshape(batch_size * k, seq_len)
        decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
        decoded_preds = [decoded_preds[i * k:(i + 1) * k] for i in range(batch_size)]
    else:  # (batch, seq_len)
        decoded_preds = [[tokenizer.decode(p, skip_special_tokens=True)] for p in preds]

    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    top1_correct = 0
    tanimotos = []
    valids = []

    for k_preds, label in zip(decoded_preds, decoded_labels):
        label_c = canonicalize(label)
        

        if label_c is None:
            tanimotos.append(0)
            valids.append(0)
            continue
        valids.append(bool(Chem.MolFromSmiles(label_c)))
        best_tani = 0

        for i, pred in enumerate(k_preds):
            p_c = canonicalize(pred)
            if p_c is None:
                continue

            tani = tanimoto(p_c, label_c)
            best_tani = max(best_tani, tani)

            if p_c == label_c:
                if i == 0:
                    top1_correct += 1
                break

        tanimotos.append(best_tani)

    canonical_top1 = top1_correct / len(decoded_labels)
    mean_tanimoto = sum(tanimotos) / len(tanimotos)
    validity = sum(valids) / len(valids)

    logger.info(f"Canonical Top-1 Accuracy: {canonical_top1:.3f}")
    logger.info(f"Mean Tanimoto: {mean_tanimoto:.3f}")
    logger.info(f"Validity: {validity:.3f}")

    return {
        "canonical_top1": canonical_top1,
        "mean_tanimoto": mean_tanimoto,
        "validity": validity,
    }

# %%
train_dataset_small = tokenized_datasets["train"].shuffle(seed=42).select(range(40000))
val_dataset_small = tokenized_datasets["val"].shuffle(seed=42).select(range(3000))
test_dataset_small = tokenized_datasets["test"].shuffle(seed=42).select(range(3000))

train_dataset = tokenized_datasets["train"]
val_dataset = tokenized_datasets["val"]
test_dataset = tokenized_datasets["test"]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 409035
# })

# %%
from transformers import Trainer, TrainingArguments, T5ForConditionalGeneration

# %%
def model_init():
    model = T5ForConditionalGeneration.from_pretrained("t5-base")
    model.resize_token_embeddings(len(tokenizer))
    return model

def preprocess_logits_for_metrics(logits, labels):
    if isinstance(logits, tuple):
        logits = logits[0]
    return logits.argmax(dim=-1), labels

args = TrainingArguments(
    output_dir="t5-small-mit-separated",
    eval_strategy="steps",
    save_strategy="steps",
    learning_rate=1e-4,
    # per_device_train_batch_size=64,
    auto_find_batch_size=True,
    per_device_eval_batch_size=16,
    warmup_ratio=0.1,
    max_steps=10,
    save_steps=10,
    eval_steps=10,
    # num_train_epochs=1,
    logging_strategy="steps",
    logging_steps=100,
    report_to="tensorboard",
    weight_decay=0.05,
    logging_dir="./logs",
    greater_is_better=True,
    metric_for_best_model="canonical_top1",
    load_best_model_at_end=True,
    gradient_checkpointing=True,
    eval_accumulation_steps=128,
    fp16=True,
)

trainer = Trainer(
    model_init=model_init,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=lambda eval_pred: compute_metrics(eval_pred, tokenizer),
    preprocess_logits_for_metrics=preprocess_logits_for_metrics,
)

trainer.train(resume_from_checkpoint=False)


# best_trial = trainer.hyperparameter_search(
#     direction="minimize",
#     backend="optuna",
#     n_trials=5,
#     hp_space=lambda trial: {
#         "learning_rate": trial.suggest_loguniform("learning_rate", 1e-6, 1e-4),
#         "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [8, 16]),
#         "weight_decay": trial.suggest_float("weight_decay", 0, 0.3),
#     },
# )

# best_trial
# Out:
# C:\Users\Happy\AppData\Local\Temp\ipykernel_53628\1270383166.py:37: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 14, 'bos_token_id': 15, 'pad_token_id': 179}.
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:52, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Canonical Top1</th>
#       <th>Mean Tanimoto</th>
#       <th>Validity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.462448</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.910000</td>
#     </tr>
#   </tbody>
# </table><p>
# [23:10:37] SMILES Parse Error: syntax error while parsing: -))1ccc=77=Oc7I)>7ccc>
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -))1ccc=77=Oc7I)>7ccc>
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-))1ccc=77=Oc7I)>7ccc>' for input: '-))1ccc=77=Oc7I)>7ccc>'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CccccC)c1cc7ccccccc1cnccc-)c1cc1cccccc>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CccccC)c1cc7ccccccc1cnccc-)c1cc1cccccc>
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CccccC)c1cc7ccccccc1cnccc-)c1cc1cccccc>C' for input: '-)CccccC)c1cc7ccccccc1cnccc-)c1cc1cccccc>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C3>cccC27cC2CCCO)C)11C2332CCCC3CC33)Cc3>7
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C3>cccC27cC2CCCO)C)11C2332CCCC3CC33)Cc3>
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C3>cccC27cC2CCCO)C)11C2332CCCC3CC33)Cc3>7' for input: '-C3>cccC27cC2CCCO)C)11C2332CCCC3CC33)Cc3>7'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -COCC=CF(CC3CC(CC)111CC3CCCOCC3C)))O)CCO)C)3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -COCC=CF(CC3CC(CC)111CC3CCCOCC3C)))O)CCO)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-COCC=CF(CC3CC(CC)111CC3CCCOCC3C)))O)CCO)C)3' for input: '-COCC=CF(CC3CC(CC)111CC3CCCOCC3C)))O)CCO)C)3'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CC32CCC3CCCCCCCO.CCOCCCCCC12CC.CCC.Ccccccc1>CCCCO.=
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CC32CCC3CCCCCCCO.CCOCCCCCC12CC.CCC.Ccccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CC32CCC3CCCCCCCO.CCOCCCCCC12CC.CCC.Ccccccc1>CCCCO.=' for input: '-CC32CCC3CCCCCCCO.CCOCCCCCC12CC.CCC.Ccccccc1>CCCCO.='
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCC)CcCCCCCcC1cc1CCc11C))O)c)c1>7
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCC)CcCCCCCcC1cc1CCc11C))O)c)c1>7
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCC)CcCCCCCcC1cc1CCc11C))O)c)c1>7' for input: '-)CCC)CcCCCCCcC1cc1CCc11C))O)c)c1>7'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cccccc2c1cc2cc32c77cccc33ccccc3c)n7nn3ccccc1cc
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cccccc2c1cc2cc32c77cccc33ccccc3c)n7nn3cc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cccccc2c1cc2cc32c77cccc33ccccc3c)n7nn3ccccc1cc' for input: '-cccccc2c1cc2cc32c77cccc33ccccc3c)n7nn3ccccc1cc'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCOCC)cc)ccc)C-Cc)ccCCC33CccCcCccc3C3cCCc)33)OC3c3)33CCccc)
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCOCC)cc)ccc)C-Cc)ccCCC33CccCcCccc3C3
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCOCC)cc)ccc)C-Cc)ccCCC33CccCcCccc3C3cCCc)33)OC3c3)33CCccc)' for input: '-CCCCCOCC)cc)ccc)C-Cc)ccCCC33CccCcCccc3C3cCCc)33)OC3c3)33CCccc)'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -2CCCCCCC)FF)F)FF(FCFFC3)CC3Cccccccc2cCcccccFcccc2)cCFccccccccccc2cccccccc8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -2CCCCCCC)FF)F)FF(FCFFC3)CC3Cccccccc2cCcc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-2CCCCCCC)FF)F)FF(FCFFC3)CC3Cccccccc2cCcccccFcccc2)cCFccccccccccc2cccccccc8' for input: '-2CCCCCCC)FF)F)FF(FCFFC3)CC3Cccccccc2cCcccccFcccc2)cCFccccccccccc2cccccccc8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCCCC))CO)OC(CO)CC()CCCCCCCCC)(O)C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCCCC))CO)OC(CO)CC()CCCCCCCCC)(O)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCCCC))CO)OC(CO)CC()CCCCCCCCC)(O)C' for input: '-CCCCCCCC))CO)OC(CO)CC()CCCCCCCCC)(O)C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CN.1cccc1)cccc12>7
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CN.1cccc1)cccc12>7
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CN.1cccc1)cccc12>7' for input: '-CN.1cccc1)cccc12>7'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)ccccc22C)2OCCCc2ccccccC3cccccccc2cc1cc2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)ccccc22C)2OCCCc2ccccccC3cccccccc2cc1cc2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)ccccc22C)2OCCCc2ccccccC3cccccccc2cc1cc2' for input: '-)ccccc22C)2OCCCc2ccccccC3cccccccc2cc1cc2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -FC7CCCCFCF()CCCCCCC)FF(OCC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -FC7CCCCFCF()CCCCCCC)FF(OCC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-FC7CCCCFCF()CCCCCCC)FF(OCC' for input: '-FC7CCCCFCF()CCCCCCC)FF(OCC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -Oc1cccccOcCOOcCcOcCcccccccccCcccccccccCccccccccccccc
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -Oc1cccccOcCOOcCcOcCcccccccccCcccccccccCc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-Oc1cccccOcCOOcCcOcCcccccccccCcccccccccCccccccccccccc' for input: '-Oc1cccccOcCOOcCcOcCcccccccccCcccccccccCccccccccccccc'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -COCO.OcOcc[SH3+]cccCc2)ccs1)s1>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -COCO.OcOcc[SH3+]cccCc2)ccs1)s1>C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-COCO.OcOcc[SH3+]cccCc2)ccs1)s1>C' for input: '-COCO.OcOcc[SH3+]cccCc2)ccs1)s1>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -77.CF)F))FF)F)FF))FF)F)F
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -77.CF)F))FF)F)FF))FF)F)F
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-77.CF)F))FF)F)FF))FF)F)F' for input: '-77.CF)F))FF)F)FF))FF)F)F'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCccccccccCcCCCc1cccccCCCCCCCCCC1cccccccccCCCCCCCCCCCCcCcccC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCccccccccCcCCCc1cccccCCCCCCCCCC1ccccccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCccccccccCcCCCc1cccccCCCCCCCCCC1cccccccccCCCCCCCCCCCCcCcccC' for input: '-CCccccccccCcCCCc1cccccCCCCCCCCCC1cccccccccCCCCCCCCCCCCcCcccC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C>1c11cOcCcCcCcO)N1cc)
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C>1c11cOcCcCcCcO)N1cc)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C>1c11cOcCcCcCcO)N1cc)' for input: '-C>1c11cOcCcCcCcO)N1cc)'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cccccC)ccO)cC1n1cc1c)FF)F)Fc11c)FFc)FCFC)c)Fcccc)1>ccc11nc1ccc1cc>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cccccC)ccO)cC1n1cc1c)FF)F)Fc11c)FFc)FCFC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cccccC)ccO)cC1n1cc1c)FF)F)Fc11c)FFc)FCFC)c)Fcccc)1>ccc11nc1ccc1cc>C' for input: '-cccccC)ccO)cC1n1cc1c)FF)F)Fc11c)FFc)FCFC)c)Fcccc)1>ccc11nc1ccc1cc>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCC2)ccCc2)nc(nccccccc2cnc(2cccccc)ccn2ccccc1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCC2)ccCc2)nc(nccccccc2cnc(2cccccc)ccn2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCC2)ccCc2)nc(nccccccc2cnc(2cccccc)ccn2ccccc1' for input: '-)CCC2)ccCc2)nc(nccccccc2cnc(2cccccc)ccn2ccccc1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -))ccCcccC))2))2)2cccc)(N1)C)nCc)cc1c)cc2cN)c)cCc)cc2c)cc2)NC()cNcN1())1C)CO)Nc)cc2cc)c))C1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -))ccCcccC))2))2)2cccc)(N1)C)nCc)cc1c)cc2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-))ccCcccC))2))2)2cccc)(N1)C)nCc)cc1c)cc2cN)c)cCc)cc2c)cc2)NC()cNcN1())1C)CO)Nc)cc2cc)c))C1' for input: '-))ccCcccC))2))2)2cccc)(N1)C)nCc)cc1c)cc2cN)c)cCc)cc2c)cc2)NC()cNcN1())1C)CO)Nc)cc2cc)c))C1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -I1>2CO.71=nnnC1CCCC11c2O.n7772nc22)c222cccCN1C2c22222c>2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -I1>2CO.71=nnnC1CCCC11c2O.n7772nc22)c222c
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-I1>2CO.71=nnnC1CCCC11c2O.n7772nc22)c222cccCN1C2c22222c>2' for input: '-I1>2CO.71=nnnC1CCCC11c2O.n7772nc22)c222cccCN1C2c22222c>2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)cccc7ccc-c2)c33S-111CC111CCcccccnccc3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)cccc7ccc-c2)c33S-111CC111CCcccccnccc3
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)cccc7ccc-c2)c33S-111CC111CCcccccnccc3' for input: '-)cccc7ccc-c2)c33S-111CC111CCcccccnccc3'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CFCCnFCn)ccccccFNcccccccc2)cc333cnccccc)cc3c)ncc)nccccccc
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CFCCnFCn)ccccccFNcccccccc2)cc333cnccccc)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CFCCnFCn)ccccccFNcccccccc2)cc333cnccccc)cc3c)ncc)nccccccc' for input: '-CFCCnFCn)ccccccFNcccccccc2)cc333cnccccc)cc3c)ncc)nccccccc'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -IccccccccccIcc3ccc)ncccccccc3)c1cc>1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -IccccccccccIcc3ccc)ncccccccc3)c1cc>1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-IccccccccccIcc3ccc)ncccccccc3)c1cc>1' for input: '-IccccccccccIcc3ccc)ncccccccc3)c1cc>1'
# [23:10:37] Explicit valence for atom # 1 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C.1c2ccccccccccccCO>>cccccc2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C.1c2ccccccccccccCO>>cccccc2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C.1c2ccccccccccccCO>>cccccc2' for input: '-C.1c2ccccccccccccCO>>cccccc2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)O)cCCcccccc3cccccCcc)Cc)ccccccC(CC(cccC)2)cccc)CccccccccO(c)
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)O)cCCcccccc3cccccCcc)Cc)ccccccC(CC(cccC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)O)cCCcccccc3cccccCcc)Cc)ccccccC(CC(cccC)2)cccc)CccccccccO(c)' for input: '-)O)cCCcccccc3cccccCcc)Cc)ccccccC(CC(cccC)2)cccc)CccccccccO(c)'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)OCCCC)cccccc))CO1c)cccc)-)C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)OCCCC)cccccc))CO1c)cccc)-)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)OCCCC)cccccc))CO1c)cccc)-)C' for input: '-)OCCCC)cccccc))CO1c)cccc)-)C'
# [23:10:37] Explicit valence for atom # 1 C, 6, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C4CO)SCO)SSS=CCO)CCC(CCOCCcccccc3c)2nccccO[AlH2-]CCCO)CO)Cccccccc)()(C)CCCcccCCCcc4(8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C4CO)SCO)SSS=CCO)CCC(CCOCCcccccc3c)2nccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C4CO)SCO)SSS=CCO)CCC(CCOCCcccccc3c)2nccccO[AlH2-]CCCO)CO)Cccccccc)()(C)CCCcccCCCcc4(8' for input: '-C4CO)SCO)SSS=CCO)CCC(CCOCCcccccc3c)2nccccO[AlH2-]CCCO)CO)Cccccccc)()(C)CCCcccCCCcc4(8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -c1cccccC-Cccccc1c7ccccccccc
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -c1cccccC-Cccccc1c7ccccccccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-c1cccccC-Cccccc1c7ccccccccc' for input: '-c1cccccC-Cccccc1c7ccccccccc'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C2C2c2nccCcn12nc>2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C2C2c2nccCcn12nc>2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C2C2c2nccCcn12nc>2' for input: '-C2C2c2nccCcn12nc>2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C>NCO>c1NcC1))c1(COC)cO>1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C>NCO>c1NcC1))c1(COC)cO>1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C>NCO>c1NcC1))c1(COC)cO>1' for input: '-C>NCO>c1NcC1))c1(COC)cO>1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -2Cc2c2)2)2O2C))c)cc22c)ccc22c2ccc2ccc22c2c2cc2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -2Cc2c2)2)2O2C))c)cc22c)ccc22c2ccc2ccc22c
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-2Cc2c2)2)2O2C))c)cc22c)ccc22c2ccc2ccc22c2c2cc2' for input: '-2Cc2c2)2)2O2C))c)cc22c)ccc22c2ccc2ccc22c2c2cc2'
# [23:10:37] Can't kekulize mol.  Unkekulized atoms: 8 9 10 11 15
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCc1cccccccccccc>8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCc1cccccccccccc>8
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCc1cccccccccccc>8' for input: '-CCCc1cccccccccccc>8'
# [23:10:37] Explicit valence for atom # 11 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C>Cl3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C>Cl3
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C>Cl3' for input: '-C>Cl3'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)Ccccccc)CO2C)cccc)cc))cc11)2c)c))2)222c)c)c)Cc2cC)))c))c))C)2c3)1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)Ccccccc)CO2C)cccc)cc))cc11)2c)c))2)222c
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)Ccccccc)CO2C)cccc)cc))cc11)2c)c))2)222c)c)c)Cc2cC)))c))c))C)2c3)1' for input: '-)Ccccccc)CO2C)cccc)cc))cc11)2c)c))2)222c)c)c)Cc2cC)))c))c))C)2c3)1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cCcCOCC111OCC1ccccc1>C1>ccc11.1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cCcCOCC111OCC1ccccc1>C1>ccc11.1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cCcCOCC111OCC1ccccc1>C1>ccc11.1' for input: '-cCcCOCC111OCC1ccccc1>C1>ccc11.1'
# [23:10:37] Explicit valence for atom # 5 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCCCCCCC)cCc)C))O)C(O)CS()CcCc))C)CC)C)1)c22C7Cc2cC)))
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCCCCCCC)cCc)C))O)C(O)CS()CcCc))C)CC)C)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCCCCCCC)cCc)C))O)C(O)CS()CcCc))C)CC)C)1)c22C7Cc2cC)))' for input: '-)CCCCCCCC)cCc)C))O)C(O)CS()CcCc))C)CC)C)1)c22C7Cc2cC)))'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C>Ccc1111ClNCOCc)CCCOCCO)C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C>Ccc1111ClNCOCc)CCCOCCO)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C>Ccc1111ClNCOCc)CCCOCCO)C' for input: '-C>Ccc1111ClNCOCc)CCCOCCO)C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)O=CccC)CC)CCCCCC=C)c)ccccccO2ccccccccCC)c2cccc1)1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)O=CccC)CC)CCCCCC=C)c)ccccccO2ccccccccCC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)O=CccC)CC)CCCCCC=C)c)ccccccO2ccccccccCC)c2cccc1)1' for input: '-)O=CccC)CC)CCCCCC=C)c)ccccccO2ccccccccCC)c2cccc1)1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -NCc>ccccC22Ccccc2c22cc2cccc2c2cc22c2c2n21C11Ccc2CcnOO2C3C33ccc2ccccccccn
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -NCc>ccccC22Ccccc2c22cc2cccc2c2cc22c2c2n2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-NCc>ccccC22Ccccc2c22cc2cccc2c2cc22c2c2n21C11Ccc2CcnOO2C3C33ccc2ccccccccn' for input: '-NCc>ccccC22Ccccc2c22cc2cccc2c2cc22c2c2n21C11Ccc2CcnOO2C3C33ccc2ccccccccn'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCC=CC=CCCC)CC)CCCC22CcCcccC)CCcccCC3c12.C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCC=CC=CCCC)CC)CCCC22CcCcccC)CCcccCC3c12
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCC=CC=CCCC)CC)CCCC22CcCcccC)CCcccCC3c12.C' for input: '-CCC=CC=CCCC)CC)CCCC22CcCcccC)CCcccCC3c12.C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -c1CCCC)-))cCCC1C)))cC1CCccccccccCC2cccc22)CcCCC)))
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -c1CCCC)-))cCCC1C)))cC1CCccccccccCC2cccc2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-c1CCCC)-))cCCC1C)))cC1CCccccccccCC2cccc22)CcCCC)))' for input: '-c1CCCC)-))cCCC1C)))cC1CCccccccccCC2cccc22)CcCCC)))'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -1Cccccccccc1Cc11C1C111111CCCCC11C1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -1Cccccccccc1Cc11C1C111111CCCCC11C1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-1Cccccccccc1Cc11C1C111111CCCCC11C1' for input: '-1Cccccccccc1Cc11C1C111111CCCCC11C1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -.OCCCCCC2NccccN1>CCCCC2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -.OCCCCCC2NccccN1>CCCCC2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-.OCCCCCC2NccccN1>CCCCC2' for input: '-.OCCCCCC2NccccN1>CCCCC2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCOCC)(C))COCC)C))O)COCF2Fcc22CCcnccCF2O)C2cccn2cc8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCOCC)(C))COCC)C))O)COCF2Fcc22CCcnccC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCOCC)(C))COCC)C))O)COCF2Fcc22CCcnccCF2O)C2cccn2cc8' for input: '-CCCCCOCC)(C))COCC)C))O)COCF2Fcc22CCcnccCF2O)C2cccn2cc8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -OCOCOCCO(>OCcC222cCCcc)CcCccCC(OCO)cCO1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -OCOCOCCO(>OCcC222cCCcc)CcCccCC(OCO)cCO1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-OCOCOCCO(>OCcC222cCCcc)CcCccCC(OCO)cCO1' for input: '-OCOCOCCO(>OCcC222cCCcc)CcCccCC(OCO)cCO1'
# [23:10:37] Explicit valence for atom # 1 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -NcCNc))C1ccccc111Ocnnccccncccn1c1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -NcCNc))C1ccccc111Ocnnccccncccn1c1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-NcCNc))C1ccccc111Ocnnccccncccn1c1' for input: '-NcCNc))C1ccccc111Ocnnccccncccn1c1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -.ccccc1c7CCCNC7Cc7ccccC)c1cc2)2ccc1cc777)8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -.ccccc1c7CCCNC7Cc7ccccC)c1cc2)2ccc1cc777
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-.ccccc1c7CCCNC7Cc7ccccC)c1cc2)2ccc1cc777)8' for input: '-.ccccc1c7CCCNC7Cc7ccccC)c1cc2)2ccc1cc777)8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)cCc2c2C)cc2)cCCCc222c2)c2c2)c2cc222c1cc
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)cCc2c2C)cc2)cCCCc222c2)c2c2)c2cc222c1cc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)cCc2c2C)cc2)cCCCc222c2)c2c2)c2cc222c1cc' for input: '-)cCc2c2C)cc2)cCCCc222c2)c2c2)c2cc222c1cc'
# [23:10:37] Explicit valence for atom # 10 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CC2COCCCC22CCC)C3)13c)c3[OH-]B22)C2CC2C)2)233ccCo3n3)c3c3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CC2COCCCC22CCC)C3)13c)c3[OH-]B22)C2CC2C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CC2COCCCC22CCC)C3)13c)c3[OH-]B22)C2CC2C)2)233ccCo3n3)c3c3' for input: '-)CC2COCCCC22CCC)C3)13c)c3[OH-]B22)C2CC2C)2)233ccCo3n3)c3c3'
# [23:10:37] Explicit valence for atom # 1 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCNNcCCCCc[SH3+]ccCCc-2c2Cc-2cCCOCcc(1c33cccNccNcccc)2O)C))2)2C)-)[BH]
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCNNcCCCCc[SH3+]ccCCc-2c2Cc-2cCCOCcc(1c
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCNNcCCCCc[SH3+]ccCCc-2c2Cc-2cCCOCcc(1c33cccNccNcccc)2O)C))2)2C)-)[BH]' for input: '-)CCNNcCCCCc[SH3+]ccCCc-2c2Cc-2cCCOCcc(1c33cccNccNcccc)2O)C))2)2C)-)[BH]'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCO)c)O)ccCccCC)cC2cCC-Cc(C)CC33)CCnc((C)3C)c)c(cncFSCcc(nO)cc((C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCO)c)O)ccCccCC)cC2cCC-Cc(C)CC33)CCnc((
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCO)c)O)ccCccCC)cC2cCC-Cc(C)CC33)CCnc((C)3C)c)c(cncFSCcc(nO)cc((C' for input: '-CCCO)c)O)ccCccCC)cC2cCC-Cc(C)CC33)CCnc((C)3C)c)c(cncFSCcc(nO)cc((C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)cccccccccc3cO)Nc))nn5n7777ccccccccccccC)O)cC((CCCc)cccc3cc>
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)cccccccccc3cO)Nc))nn5n7777ccccccccccccC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)cccccccccc3cO)Nc))nn5n7777ccccccccccccC)O)cC((CCCc)cccc3cc>' for input: '-)cccccccccc3cO)Nc))nn5n7777ccccccccccccC)O)cC((CCCc)cccc3cc>'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CcccCcc2C2)FF)F)FccoC11(CcO1cccccCccccccccnc>1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CcccCcc2C2)FF)F)FccoC11(CcO1cccccCcccccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CcccCcc2C2)FF)F)FccoC11(CcO1cccccCccccccccnc>1' for input: '-CcccCcc2C2)FF)F)FccoC11(CcO1cccccCccccccccnc>1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cF1=CCS)CCFF)CF1ccc22ccc222Fccc33cF))FF)F)ccccFF)FF)F)cccFF)8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cF1=CCS)CCFF)CF1ccc22ccc222Fccc33cF))FF)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cF1=CCS)CCFF)CF1ccc22ccc222Fccc33cF))FF)F)ccccFF)FF)F)cccFF)8' for input: '-cF1=CCS)CCFF)CF1ccc22ccc222Fccc33cF))FF)F)ccccFF)FF)F)cccFF)8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCN)2CCCCCCCCCCC.CCC.CCO)ccC2cccccccC1O)Cc2ccccc2N>c
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCN)2CCCCCCCCCCC.CCC.CCO)ccC2cccccccC1O)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCN)2CCCCCCCCCCC.CCC.CCO)ccC2cccccccC1O)Cc2ccccc2N>c' for input: '-CCN)2CCCCCCCCCCC.CCC.CCO)ccC2cccccccC1O)Cc2ccccc2N>c'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCCCO))cCCCO)C)CCCOC)C)Cc)11cCC)))2)CCCOCCC2CCCC)C)C)))CcccC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCCCO))cCCCO)C)CCCOC)C)Cc)11cCC)))2)CCC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCCCO))cCCCO)C)CCCOC)C)Cc)11cCC)))2)CCCOCCC2CCCC)C)C)))CcccC' for input: '-)CCCCO))cCCCO)C)CCCOC)C)Cc)11cCC)))2)CCCOCCC2CCCC)C)C)))CcccC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -ccnc2ncccCcc)ccccccnc2ccn>ncn))
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -ccnc2ncccCcc)ccccccnc2ccn>ncn))
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-ccnc2ncccCcc)ccccccnc2ccn>ncn))' for input: '-ccnc2ncccCcc)ccccccnc2ccn>ncn))'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CccCcccccccccccCOCcCCCcC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CccCcccccccccccCOCcCCCcC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CccCcccccccccccCOCcCCCcC' for input: '-)CccCcccccccccccCOCcCCCcC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CC1>Cc)cccCcccccccccCOC1))
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CC1>Cc)cccCcccccccccCOC1))
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CC1>Cc)cccCcccccccccCOC1))' for input: '-CC1>Cc)cccCcccccccccCOC1))'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCOCccccccCCCCOCc2CcccccccCCc1cc1ccccc2)CCCCCCCcc1ccC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCOCccccccCCCCOCc2CcccccccCCc1cc1cccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCOCccccccCCCCOCc2CcccccccCCc1cc1ccccc2)CCCCCCCcc1ccC' for input: '-CCCCCOCccccccCCCCOCc2CcccccccCCc1cc1ccccc2)CCCCCCCcc1ccC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C71ccccc2c2cCCCC7CcC->C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C71ccccc2c2cCCCC7CcC->C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C71ccccc2c2cCCCC7CcC->C' for input: '-C71ccccc2c2cCCCC7CcC->C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCC12CC)2c)ccc)cccCCc333CCCCCCCCCC))cCccccc()
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCC12CC)2c)ccc)cccCCc333CCCCCCCCCC))cCcc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCC12CC)2c)ccc)cccCCc333CCCCCCCCCC))cCccccc()' for input: '-CCC12CC)2c)ccc)cccCCc333CCCCCCCCCC))cCccccc()'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCCCCFFFCFccccccc1ccn2cc1cccccccFCC)CF)F)FFFC)F1ccccccc)8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCCCCFFFCFccccccc1ccn2cc1cccccccFCC)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCCCCFFFCFccccccc1ccn2cc1cccccccFCC)CF)F)FFFC)F1ccccccc)8' for input: '-CCCCCCCCFFFCFccccccc1ccn2cc1cccccccFCC)CF)F)FFFC)F1ccccccc)8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -Cncncn)CCcCCCC)C32CCCC3C)Cnc>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -Cncncn)CCcCCCC)C32CCCC3C)Cnc>C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-Cncncn)CCcCCCC)C32CCCC3C)Cnc>C' for input: '-Cncncn)CCcCCCC)C32CCCC3C)Cnc>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCO>CCC7CCCc=cCCOCCC>CCC2ccc222cocccc(O>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCO>CCC7CCCc=cCCOCCC>CCC2ccc222cocccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCO>CCC7CCCc=cCCOCCC>CCC2ccc222cocccc(O>C' for input: '-CCCCCO>CCC7CCCc=cCCOCCC>CCC2ccc222cocccc(O>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -3[SH3+]CCCO2cnc3cnC2cCCCO3>2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -3[SH3+]CCCO2cnc3cnC2cCCCO3>2
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-3[SH3+]CCCO2cnc3cnC2cCCCO3>2' for input: '-3[SH3+]CCCO2cnc3cnC2cCCCO3>2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cc>ccccCC)C)C1cc(7ccccc77ccc22c)3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cc>ccccCC)C)C1cc(7ccccc77ccc22c)3
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cc>ccccCC)C)C1cc(7ccccc77ccc22c)3' for input: '-cc>ccccCC)C)C1cc(7ccccc77ccc22c)3'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCO>CCO>C>CCCCCCCCCCCCCO>C>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCO>CCO>C>CCCCCCCCCCCCCO>C>C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCO>CCO>C>CCCCCCCCCCCCCO>C>C' for input: '-CCCCCO>CCO>C>CCCCCCCCCCCCCO>C>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -==CCCCC1Oc1cccc.CCCOCCCCCCcc2cc11cC22cC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -==CCCCC1Oc1cccc.CCCOCCCCCCcc2cc11cC22cC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-==CCCCC1Oc1cccc.CCCOCCCCCCcc2cc11cC22cC' for input: '-==CCCCC1Oc1cccc.CCCOCCCCCCcc2cc11cC22cC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cCCCcOCc2ccccc2P2c2cc22c7O7cO2c)72(c))2)2)))
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cCCCcOCc2ccccc2P2c2cc22c7O7cO2c)72(c))2)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cCCCcOCc2ccccc2P2c2cc22c7O7cO2c)72(c))2)2)))' for input: '-cCCCcOCc2ccccc2P2c2cc22c7O7cO2c)72(c))2)2)))'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -))c[SH3+]cccCCO>7ccc>CCC111CC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -))c[SH3+]cccCCO>7ccc>CCC111CC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-))c[SH3+]cccCCO>7ccc>CCC111CC' for input: '-))c[SH3+]cccCCO>7ccc>CCC111CC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -11ccc2ccC121c3337771777c271c)cc2c2cc2cF11cc222cc2
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -11ccc2ccC121c3337771777c271c)cc2c2cc2cF1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-11ccc2ccC121c3337771777c271c)cc2c2cc2cF11cc222cc2' for input: '-11ccc2ccC121c3337771777c271c)cc2c2cc2cF11cc222cc2'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCCCOCC)CCO1[SH3+]cccC)Cc(cC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCCCOCC)CCO1[SH3+]cccC)Cc(cC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCCCOCC)CCO1[SH3+]cccC)Cc(cC' for input: '-)CCCCOCC)CCO1[SH3+]cccC)Cc(cC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CC=CCC>NCCccccccc222o2c2CCnCCNCCCO>N>12nccccccNccccccC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CC=CCC>NCCccccccc222o2c2CCnCCNCCCO>N>12n
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CC=CCC>NCCccccccc222o2c2CCnCCNCCCO>N>12nccccccNccccccC' for input: '-CC=CCC>NCCccccccc222o2c2CCnCCNCCCO>N>12nccccccNccccccC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)COCOCFc>1cc)CC)OCOCCCccccC
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)COCOCFc>1cc)CC)OCOCCCccccC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)COCOCFc>1cc)CC)OCOCCCccccC' for input: '-)COCOCFc>1cc)CC)OCOCCCccccC'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -Occccccc)c-cccccc>ccc32cOOcOcccccccc2c3)nccc)c
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -Occccccc)c-cccccc>ccc32cOOcOcccccccc2c3)
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-Occccccc)c-cccccc>ccc32cOOcOcccccccc2c3)nccc)c' for input: '-Occccccc)c-cccccc>ccc32cOOcOcccccccc2c3)nccc)c'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -Cc[SH3+]cccCccncc-C)C3C33)CccnC3)O)CCcNcccc)3)33CC3COCCC(CCCC)C)C)))cc)ccccc3)Cccc3
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -Cc[SH3+]cccCccncc-C)C3C33)CccnC3)O)CCcNc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-Cc[SH3+]cccCccncc-C)C3C33)CccnC3)O)CCcNcccc)3)33CC3COCCC(CCCC)C)C)))cc)ccccc3)Cccc3' for input: '-Cc[SH3+]cccCccncc-C)C3C33)CccnC3)O)CCcNcccc)3)33CC3COCCC(CCCC)C)C)))cc)ccccc3)Cccc3'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -cCCCCCCCCc1cccc>CccC-C1cccccccCccc>1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -cCCCCCCCCc1cccc>CccC-C1cccccccCccc>1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-cCCCCCCCCc1cccc>CccC-C1cccccccCccc>1' for input: '-cCCCCCCCCc1cccc>CccC-C1cccccccCccc>1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CC1ccccB1c-cO2c1cnnn2n13c333cB1-333cC)c13cnc3ccccc3cnc1cn
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CC1ccccB1c-cO2c1cnnn2n13c333cB1-333cC)c1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CC1ccccB1c-cO2c1cnnn2n13c333cB1-333cC)c13cnc3ccccc3cnc1cn' for input: '-CC1ccccB1c-cO2c1cnnn2n13c333cB1-333cC)c13cnc3ccccc3cnc1cn'
# [23:10:37] Explicit valence for atom # 30 N, 4, is greater than permitted
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCCNNCCCCO)CC))CCCCCCc3c2c377ccccc3)CCC)cc)cc2C)cccc)
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCCNNCCCCO)CC))CCCCCCc3c2c377ccccc3)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCCNNCCCCO)CC))CCCCCCc3c2c377ccccc3)CCC)cc)cc2C)cccc)' for input: '-CCCCCCNNCCCCO)CC))CCCCCCc3c2c377ccccc3)CCC)cc)cc2C)cccc)'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCc1ccCcCcccCCCC)cCCC)CCCCCCccccCC1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCc1ccCcCcccCCCC)cCCC)CCCCCCccccCC1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCc1ccCcCcccCCCC)cCCC)CCCCCCccccCC1' for input: '-CCCCc1ccCcCcccCCCC)cCCC)CCCCCCccccCC1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -1cccccCc2ccc222cccc>C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -1cccccCc2ccc222cccc>C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-1cccccCc2ccc222cccc>C' for input: '-1cccccCc2ccc222cccc>C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -OCC)OCccccccc)c)2c2c-)2c)))c)c)c32)ccccC)c)C))O)c))cCO))Cc)C)Cc))CccCc2c))1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -OCC)OCccccccc)c)2c2c-)2c)))c)c)c32)ccccC
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-OCC)OCccccccc)c)2c2c-)2c)))c)c)c32)ccccC)c)C))O)c))cCO))Cc)C)Cc))CccCc2c))1' for input: '-OCC)OCccccccc)c)2c2c-)2c)))c)c)c32)ccccC)c)C))O)c))cCO))Cc)C)Cc))CccCc2c))1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)C)cc)ccccc)cc)cccc=ccc-cc)8
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)C)cc)ccccc)cc)cccc=ccc-cc)8
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)C)cc)ccccc)cc)cccc=ccc-cc)8' for input: '-)C)cc)ccccc)cc)cccc=ccc-cc)8'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -.OccCcccccccCccccccccccc1ccc1ccCC1)ccccccc1cc1c.)
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -.OccCcccccccCccccccccccc1ccc1ccCC1)ccccc
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-.OccCcccccccCccccccccccc1ccc1ccCC1)ccccccc1cc1c.)' for input: '-.OccCcccccccCccccccccccc1ccc1ccCC1)ccccccc1cc1c.)'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -FCFC2)FFcFcFc2cnccFccF7)FFCCC)FC)FFF)C
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -FCFC2)FFcFcFc2cnccFccF7)FFCCC)FC)FFF)C
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-FCFC2)FFcFcFc2cnccFccF7)FFCCC)FC)FFF)C' for input: '-FCFC2)FFcFcFc2cnccFccF7)FFCCC)FC)FFF)C'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -)CCCCCCCCCC1cccCCcc1ccccCOCcOc)cC)1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -)CCCCCCCCCC1cccCCcc1ccccCOCcOc)cC)1
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-)CCCCCCCCCC1cccCCcc1ccccCOCcOc)cC)1' for input: '-)CCCCCCCCCC1cccCCcc1ccccCOCcOc)cC)1'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -CCCCCCCC>CCcnccnccnccnc1nn
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -CCCCCCCC>CCcnccnccnccnc1nn
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-CCCCCCCC>CCcnccnccnccnc1nn' for input: '-CCCCCCCC>CCcnccnccnccnc1nn'
# [23:10:37] SMILES Parse Error: syntax error while parsing: -C=c>ccC.CCO)cC)CSc7CO)7c7ccccccnccC)Cnc.1
# [23:10:37] SMILES Parse Error: check for mistakes around position 1:
# [23:10:37] -C=c>ccC.CCO)cC)CSc7CO)7c7ccccccnccC)Cnc.
# [23:10:37] ^
# [23:10:37] SMILES Parse Error: Failed parsing SMILES '-C=c>ccC.CCO)cC)CSc7CO)7c7ccccccnccC)Cnc.1' for input: '-C=c>ccC.CCO)cC)CSc7CO)7c7ccccccnccC)Cnc.1'
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=10, training_loss=4.328192901611328, metrics={'train_runtime': 54.072, 'train_samples_per_second': 1.48, 'train_steps_per_second': 0.185, 'total_flos': 24358315622400.0, 'train_loss': 4.328192901611328, 'epoch': 0.00019557989438685703})

# %%
metrics = trainer.evaluate(test_dataset_small)
print(metrics)

# %%
trainer.save_model("t5-mit-small-dataset-separated-lr1e-5-wd0.05-5000steps")

# %%
from transformers import BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
)

model_4bit = T5ForConditionalGeneration.from_pretrained(
    "t5-base-mit-separated/checkpoint-750",
    quantization_config=bnb_config,
    device_map="auto",
).to("cuda")

text = "C O c 1 c c c c 2 c 1 C ( C ) C ( = O ) N 2 C . N # C C I > C C O . C C [O-] . [Na+]"

inputs = tokenizer(text, return_tensors="pt", return_token_type_ids=False).to(model_4bit.device)
outputs_4bit = model_4bit.generate(**inputs, max_length=256, repetition_penalty=1.0, do_sample=False, num_return_sequences=2, num_beams=10, output_scores=True, return_dict_in_generate=True)

# print(outputs_4bit)


import torch

seq_scores = outputs_4bit.sequences_scores  # logits for each sequence
probs = torch.softmax(seq_scores, dim=0) * 100  # %
print("Scores: ", probs)

preds_4bit = tokenizer.batch_decode(outputs_4bit.sequences, skip_special_tokens=True)
for i, p in enumerate(preds_4bit):
    print(f"4-bit Model Prediction {i+1}: {p}")
# Out:
# Scores:  tensor([55.5501, 44.4499], device='cuda:0')
# 4-bit Model Prediction 1: # C O c 1 c c c c 2 c 1 C ( ( (
# 4-bit Model Prediction 2: # N # C O c 1 c c c c 2 c 1 C (

# %%
model = T5ForConditionalGeneration.from_pretrained("t5-base-mit-separated/checkpoint-100").to("cuda")

model2 = T5ForConditionalGeneration.from_pretrained("t5-small-mit-separated/checkpoint-26000").to("cuda")

model_base = T5ForConditionalGeneration.from_pretrained("t5-base").to("cuda")
model_small = T5ForConditionalGeneration.from_pretrained("t5-small").to("cuda")


inputs = tokenizer(text, return_tensors="pt", return_token_type_ids=False).to(model.device)


outputs = model.generate(**inputs, max_length=256, repetition_penalty=1, do_sample=False, num_return_sequences=2, num_beams=10)
preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
for i, p in enumerate(preds):
    print(f"Model 1 Prediction {i+1}: {p}")


outputs2 = model2.generate(**inputs, max_length=256, repetition_penalty=1.0, do_sample=False, num_return_sequences=2, num_beams=10)
preds2 = tokenizer.batch_decode(outputs2, skip_special_tokens=True)
for i, p in enumerate(preds2):
    print(f"Model 2 Prediction {i+1}: {p}")


# outputs_base = model_base.generate(**inputs, max_length=256, repetition_penalty=1.0, do_sample=False, num_return_sequences=2, num_beams=10)
# preds_base = tokenizer.batch_decode(outputs_base, skip_special_tokens=True)
# for i, p in enumerate(preds_base):
#     print(f"Base Model Prediction {i+1}: {p}")
# outputs_small = model_small.generate(**inputs, max_length=256, repetition_penalty=1.0, do_sample=False, num_return_sequences=2, num_beams=10)
# preds_small = tokenizer.batch_decode(outputs_small, skip_special_tokens=True)
# for i, p in enumerate(preds_small):
#     print(f"Small Model Prediction {i+1}: {p}")

# %%
model.save_pretrained("t5-mit-small-dataset-separated-lr1e-5-wd0.05-5000steps")
